# %%
import pandas as pd

# %% [markdown]
# Untersucht wird ein Dataset von Hugginface.co (Apache license 2.0)

# %%
strains = pd.read_csv('./csv/strains.csv')
strains.head()
# Out:
#    averageRating  cannabinoid_cbc_percentile50  cannabinoid_cbd_percentile50  \
# 0       3.000000                           NaN                           NaN
# 1       4.333333                           NaN                           NaN
# 2       4.200000                           NaN                           0.0
# 3       4.500000                           0.0                           0.0
# 4       4.114286                           0.0                           0.0
#
#    cannabinoid_cbg_percentile50  cannabinoid_thc_percentile50  \
# 0                           NaN                           NaN
# 1                           NaN                          29.0
# 2                           0.0                          23.0
# 3                           0.0                           8.0
# 4                           0.0                          18.0
#
#    cannabinoid_thcv_percentile50 category        children_slugs  \
# ...

# %%
strains.describe()
# Out:
#        averageRating  cannabinoid_cbc_percentile50  \
# count    8492.000000                   3078.000000
# mean        3.973796                      0.005523
# std         1.500643                      0.086280
# min         0.000000                      0.000000
# 25%         4.150364                      0.000000
# 50%         4.500000                      0.000000
# 75%         4.727273                      0.000000
# max         5.000000                      3.000000
#
#        cannabinoid_cbd_percentile50  cannabinoid_cbg_percentile50  \
# count                   3666.000000                   3638.000000
# mean                       0.255619                      0.743815
# std                        1.667764                      0.613575
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      1.000000
# ...

# %%
ratings = strains[[ 'name','averageRating' ]]
desc_strains = ratings.sort_values('averageRating', ascending=False)
desc_strains.to_csv('desc_strains.txt', index=True)

# %%
ratings = strains[[ 'name','averageRating' ]]
ratings[ratings["averageRating"]==5].to_csv('top_strains.txt', index=True)
